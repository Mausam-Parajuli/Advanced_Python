# %%
import csv

with open(file="try.csv" , mode='r') as f:
    reader = csv.reader(f)
    
    for row in reader:
        print(row)
# Out:
# ['Name', 'Address', 'Age']
# ['Ram', 'Biratnagar', '22']
# ['Shyam', 'Itahari', '24']
# ['Hari', 'Dharan', '23']

# %%
import csv

with open("try.csv", "r") as f:
    reader = csv.DictReader(f)
    for row in reader:
        print(row)
# Out:
# {'Name': 'Ram', 'Address': 'Biratnagar', 'Age': '22'}
# {'Name': 'Shyam', 'Address': 'Itahari', 'Age': '24'}
# {'Name': 'Hari', 'Address': 'Dharan', 'Age': '23'}

# %%
import csv

with open(file="try.csv" , mode='r') as f:
    reader = csv.DictReader(f)
    
    for row in reader:
        print(row)
        print(row['Name'] , row['Address'] , row['Age'])
# Out:
# {'Name': 'Ram', 'Address': 'Biratnagar', 'Age': '22'}
# Ram Biratnagar 22
# {'Name': 'Shyam', 'Address': 'Itahari', 'Age': '24'}
# Shyam Itahari 24
# {'Name': 'Hari', 'Address': 'Dharan', 'Age': '23'}
# Hari Dharan 23

# %%
import csv

data = [
    ["Name", "Address", "Age"],
    ["Ram", "Biratnagar", "22"],
    ["Shyam", "Itahari", "24"],
    ["Hari", "Dharan", "23"],
]

additional_data = ['Himal', "Dharan" , "23"]
with open(file="newnew.csv" , mode='w' , newline="") as f:
    writer = csv.writer(f)
    writer.writerows(data)
    
    writer.writerow(additional_data)

# %%
data = [
    {"name": "Himal", "age": 30},
    {"name": "Sajina", "age": 10},
    {"name": "Heemal", "age": 33},
]
with open(file="output.csv", mode="w") as f:
    writer = csv.DictWriter(f, fieldnames=["name", "age"])
    writer.writeheader()
    writer.writerows(data)

# %%
import pandas as pd

df = pd.read_csv('newnew.csv')    # DataFrame vanne class ko object ho.
print(df)
print(type(df))

# df["Address"] # to access individual columns
# df['Age']
# Out:
#     Name     Address  Age
# 0    Ram  Biratnagar   22
# 1  Shyam     Itahari   24
# 2   Hari      Dharan   23
# 3  Himal      Dharan   23
# <class 'pandas.core.frame.DataFrame'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     4 non-null      object
#  1   Address  4 non-null      object
#  2   Age      4 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes

# %%
df.head(2)  # to retrieve the information
# Out:
#     Name     Address  Age
# 0    Ram  Biratnagar   22
# 1  Shyam     Itahari   24

# %%
df.tail(2)
# Out:
#     Name Address  Age
# 2   Hari  Dharan   23
# 3  Himal  Dharan   23

# %%
# to view the random sample


df.sample()  # gives the different sample from the existing csv file.
# Out:
#     Name Address  Age
# 3  Himal  Dharan   23

# %%
# to check the missing values.

# df.isnull()

df.isnull().sum()  # to find out the missing values
# Out:
# Name       0
# Address    0
# Age        0
# dtype: int64

# %%
# To add the columns


df["Province"] = "Koshi"

# %%
print(df)
# Out:
#     Name     Address  Age Province
# 0    Ram  Biratnagar   22    Koshi
# 1  Shyam     Itahari   24    Koshi
# 2   Hari      Dharan   23    Koshi
# 3  Himal      Dharan   23    Koshi

# %%
# to write the csv back

df.to_csv("newwrite.csv" , index=False) # index csv file ma chaideina so we use false

# %%
data = [
    {"Roll": 1, "Name": "Ram", "English": 80, "Math": 81, "Science": 82},
    {"Roll": 2, "Name": "Shyam", "English": 79, "Math": 80, "Science": 83},
]
dataframe = pd.DataFrame(data=data)  # total vanne chaiyo. and then percentage vanne banaune.

dataframe["Total"] = dataframe["English"] + dataframe["Math"] + dataframe["Science"]
print(dataframe)
# Out:
#    Roll   Name  English  Math  Science  Total
# 0     1    Ram       80    81       82    243
# 1     2  Shyam       79    80       83    242

# %%
dataframe['Percentage'] =(dataframe['Total']/3).round(decimals=2)
print(dataframe)
# Out:
#    Roll   Name  English  Math  Science  Total  Percentage
# 0     1    Ram       80    81       82    243       81.00
# 1     2  Shyam       79    80       83    242       80.67

# %%
dataframe.to_csv("newFile.csv", index=False)

# %%
# Reading a Json File

import json
import pprint

with open(file="data.json" ,mode='r') as f:
    json_parsed = json.load(f)
    # print(json_parsed)
    pprint.pprint(json_parsed)
# Out:
# {'Additional': {'Age': 34, 'Name': 'Himal'},
#  'Address': 'Dharan',
#  'Age': 34,
#  'Name': 'Himal'}

# %%
import json 

data = {
    "Name":"Himal Bhandari",
    "Age":20,
    "Address":"Jhapa"    
}

with open(file="newJson.json", mode='w') as f:
    json.dump(data , f , indent=4)

# %%
import plotly.express as px
import pandas as pd

df = px.data.iris()

print(df.head())

fig = px.scatter(df, x= "sepal_length", y= "sepal_width")

fig.show()

fig1 = px.bar(df, x= "sepal_length", y= "species")

fig1.show()

fig1.write_html("plot.html")
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1
