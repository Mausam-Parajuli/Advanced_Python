# %%
print("hello")
# Out:
# hello

# %%
import matplotlib.pyplot as plt

# %%
squares = [1, 4, 9, 16, 25]

fig, ax = plt.subplots()
ax.plot(squares, linewidth = 3)
ax.set_title("Squares")
ax.set_xlabel("Value")
ax.set_ylabel("Squares")

plt.show()

# %%
nums = [1,2,3,4,5]
cubes = []
for num in nums:
    cubes.append(num ** 3)

fig, ax = plt.subplots()
ax.scatter(nums, cubes, color="red")
ax.plot(nums, cubes, linewidth = 4)
plt.style.use("Solarize_Light2")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x_value = range(1, 101, 5)
y_value = []
for x in x_value:
    y_value.append((np.e) * x)

fig, ax = plt.subplots()

ax.scatter(x_value, y_value, s=100, color="green")
plt.style.use("Solarize_Light2")
ax.axis([0, 101, 1, 300])

plt.savefig("eKoPower.svg")

plt.show()

# %%
# Random Walk
from random import choice

class RandomWalk:
    def __init__(self, points = 5000):
        self.points = points
        self.x_values = [0]
        self.y_values = [0]

    def fill_walk(self):
        while len(self.x_values) < self.points:
             
            x_direction = choice([1, -1])
            x_distance = choice([0, 1, 2, 3, 4])
            x_step = x_distance * x_direction

            y_direction = choice([1, -1])
            y_distance = choice([0, 1, 2, 3, 4])
            y_step = y_direction * y_distance

            if x_step == 0 and y_step == 0:
                continue

            x = self.x_values[-1] + x_step
            y = self.y_values[-1] + y_step

            self.x_values.append(x)
            self.y_values.append(y)

import matplotlib.pylab as plt

rw = RandomWalk()
rw.fill_walk()

plt.style.use('classic')

fig, ax = plt.subplots()
ax.scatter(rw.x_values, rw.y_values, color="red")
ax.set_aspect('equal')
ax.scatter(0, 0, color="blue")
ax.scatter(rw.x_values[-1], rw.y_values[-1], color="blue")

plt.savefig("random_walk.svg")
plt.show()
