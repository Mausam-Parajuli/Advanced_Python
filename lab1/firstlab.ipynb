# %%
import numpy as np
# Out:
# Running cells with 'myvenv (Python 3.13.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/DELL/Desktop/Advanced_Python/myvenv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
# Task 1
