# %%
from collections import Counter

alist = [1, 2, 1, "Ram", "Shyam", "Manav", "Ram", "Ram"]
count = Counter(alist)
print(count)
print(count[1])
print(count["Ram"])
print(type(count))
# Out:
# Counter({'Ram': 3, 1: 2, 2: 1, 'Shyam': 1, 'Manav': 1})
# 2
# 3
# <class 'collections.Counter'>

# %%
for key in count.keys():
    print(key)
# Out:
# 1
# 2
# Ram
# Shyam
# Manav

# %%
#aDict = {}
#aDict['a'] = aDict['a'] + 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 2
#       1 aDict = {}
# ----> 2 aDict['a'] = aDict['a'] + 1
#
# KeyError: 'a'

# %%
from collections import defaultdict

bDict = defaultdict(int)
bDict['a'] = bDict['a'] + 1
print(bDict)
# Out:
# defaultdict(<class 'int'>, {'a': 1})

# %%
#Doubly ended queue (Deque)
from collections import deque

queue = deque([1, 5, 6])
print(queue)
queue.append(100)
print(queue)
queue.appendleft(200)
print(queue)
queue.pop()
print(queue)
queue.popleft()
print(queue)
# Out:
# deque([1, 5, 6])
# deque([1, 5, 6, 100])
# deque([200, 1, 5, 6, 100])
# deque([200, 1, 5, 6])
# deque([1, 5, 6])

# %%
while queue:
    val = queue.pop()
    print(val)
# Out:
# 6
# 5
# 1

# %%
from collections import namedtuple

Point = namedtuple("Point", 'x y z')
p1 = Point(1,2,3)
print(p1.x, p1.y, p1.z)
x, y, z = p1
print(x, " ", y, " ", z, " ")
# Out:
# 1 2 3
# 1   2   3

# %%
#Iteratiors

alist = [1, 3, 5]
it = iter(alist)

print(next(it))
print(next(it))
print(next(it))
#print(next(it))   #lenght exceed vayepaxi error
# Out:
# 1
# 3
# 5
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[13], line 9
#       7 print(next(it))
#       8 print(next(it))
# ----> 9 print(next(it))
#
# StopIteration:

# %%
for num in alist:
    print(num)
# Out:
# 1
# 3
# 5

# %%
alist = [1,2,3,4,5]
it = iter(alist)
while True:
    try:
        num = next(it)
        print(num)
    except StopIteration:
        break
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#Generators

def squares(x):
    for i in range(1,x+1):
        #print(i*i)
        yield i*i

for x in squares(5):
    print(x)
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
#Decorators

def myDecorator(func):
    def wrapper():
        print("Before")
        func()
        print("After")
    return wrapper

# %%
@myDecorator
def sayHello():
    print("Hello")

# %%
sayHello()
# Out:
# Before
# Hello
# After

# %%
import time
def timer(func):
    def wrapper(*args, **kwargs):
        start = time.time()
        result = func(*args, **kwargs)
        end = time.time()
        print(f"Time Elapsed = {(end - start):.8f} seconds")
        return result
    return wrapper

# %%
@timer
def fact(n):
    f = 1
    for i in range(1, n+1):
        f = f * i
    return f

# %%
fact(10)
# Out:
# Time Elapsed = 0.00000548 seconds
# 3628800

# %%
#Functions and Lambda

# lambda argument : expressions

add = lambda a,b : a+b
add(1,2)
# Out:
# 3

# %%
# Use case I: Sorting

students = [("Dharan","Ram", 25), ("Biratnagar","Shyam", 10), ("Ithari","Manav", 20)]
students_sorted = sorted(students, key = lambda x : x[2])
print(students_sorted)
# Out:
# [('Biratnagar', 'Shyam', 10), ('Ithari', 'Manav', 20), ('Dharan', 'Ram', 25)]

# %%
# Use case II: Filtering

nums = [1,2,3,4,5,6,7,8,9]
evens = list(filter(lambda x: x%2 == 0, nums))
print(evens)
# Out:
# [2, 4, 6, 8]

# %%
# Use Case III: Mapping

nums = [1,2,3,4,5,6,7,8,9]
squares = list(map(lambda x: x*x, nums))
print(squares)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
cubes = [x*x*x for x in nums]
print(cubes)
# Out:
# [1, 8, 27, 64, 125, 216, 343, 512, 729]
